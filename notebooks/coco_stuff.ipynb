# %%
# Mount Google Drive to access files and save outputs persistently
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://OliverSavolainen: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@github.com/valentina98/FACT_group11
# %ls
# Out:
# Cloning into 'FACT_group11'...
# remote: Enumerating objects: 40973, done.
# remote: Counting objects: 100% (300/300), done.
# remote: Compressing objects: 100% (144/144), done.
# remote: Total 40973 (delta 185), reused 271 (delta 156), pack-reused 40673
# Receiving objects: 100% (40973/40973), 2.54 GiB | 30.79 MiB/s, done.
# Resolving deltas: 100% (238/238), done.
# Updating files: 100% (56330/56330), done.
# drive/  FACT_group11/  sample_data/

# %%
# %cd ./FACT_group11
# !git checkout coco_stuff
# Out:
# /content/FACT_group11
# Branch 'coco_stuff' set up to track remote branch 'coco_stuff' from 'origin'.
# Switched to a new branch 'coco_stuff'

# %%
# !pip install pytorchcv fiftyone openai-clip
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.4/532.4 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 35.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 61.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 19.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.9/108.9 kB 15.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 58.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ---
# **Scroll down for all seeds**

# %%
# Get the saved concepts
import shutil
source_path = '/content/drive/My Drive/conceptbanks/'
destination_path = './conceptbanks/'
shutil.copytree(source_path, destination_path)

# -------------
# # Learn concepts
# !python learn_concepts_dataset.py \
#   --dataset-name="broden" \
#   --backbone-name="clip:RN50" \
#   --n-samples=50 \
#   --out-dir="./conceptbanks/" \
#   --seed=42 \
#   --num-workers=2 # Our suggested max number of worker in current system is 2. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.

# # Save concepts
# import shutil
# source_path = './conceptbanks/'
# destination_path = '/content/drive/My Drive/conceptbanks/'
# shutil.copytree(source_path, destination_path)
# Out:
# './conceptbanks/'

# %%
# %ls ./conceptbanks
# Out:
# broden_clip:RN50_0.01_50_42.pkl  broden_clip:RN50_0.1_50_42.pkl  RN50.pt

# %%
# # Train PCBM
# !python train_pcbm.py \
#   --concept-bank="./conceptbanks/broden_clip:RN50_0.1_50_42.pkl" \
#   --dataset="coco_stuff" \
#   --backbone-name="clip:RN50" \
#   --out-dir=""  \
#   --lam=1e-3 \
#   --seed=42
# Out:
# Bank path: ./conceptbanks/broden_clip:RN50_0.1_50_42.pkl. 170 concepts will be used.
# Concept Bank is initialized.
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
# %ls
# Out:
# assets/
# conceptbanks/
# concepts/
# data/
# datasets/
# learn_concepts_dataset.py
# learn_concepts_multimodal.py
# LICENSE
# models/
# pcbm_coco_stuff__clip:RN50__broden_clip:RN50_0__lam:0.001__alpha:0.99__seed:42.ckpt
# README.md
# run_info-pcbm_coco_stuff__clip:RN50__broden_clip:RN50_0__lam:0.001__alpha:0.99__seed:42.pkl
# test-embs_coco_stuff__clip:RN50__broden_clip:RN50_0.npy
# test-lbls_coco_stuff__clip:RN50__broden_clip:RN50_0_lbls.npy
# test-proj_coco_stuff__clip:RN50__broden_clip:RN50_0.npy
# train-embs_coco_stuff__clip:RN50__broden_clip:RN50_0.npy
# training_tools/
# train-lbls_coco_stuff__clip:RN50__broden_clip:RN50_0_lbls.npy
# train_pcbm_h.py
# train_pcbm.py
# train-proj_coco_stuff__clip:RN50__broden_clip:RN50_0.npy

# %%
# import shutil
# import os

# # Destination directory
# destination_path = '/content/drive/My Drive/results/'

# # List of source file paths
# source_paths = [
#     'pcbm_coco_stuff__clip:RN50__broden_clip:RN50_0__lam:0.001__alpha:0.99__seed:42.ckpt',
#     'run_info-pcbm_coco_stuff__clip:RN50__broden_clip:RN50_0__lam:0.001__alpha:0.99__seed:42.pkl',
#     'test-embs_coco_stuff__clip:RN50__broden_clip:RN50_0.npy',
#     'test-lbls_coco_stuff__clip:RN50__broden_clip:RN50_0_lbls.npy',
#     'test-proj_coco_stuff__clip:RN50__broden_clip:RN50_0.npy',
#     'train-embs_coco_stuff__clip:RN50__broden_clip:RN50_0.npy',
#     'train-lbls_coco_stuff__clip:RN50__broden_clip:RN50_0_lbls.npy',
#     'train-proj_coco_stuff__clip:RN50__broden_clip:RN50_0.npy'
# ]

# # Copy each file to the destination directory
# for source_path in source_paths:
#     # Construct the full destination file path
#     dest_file_path = os.path.join(destination_path, os.path.basename(source_path))

#     # Copy the file
#     shutil.copy(source_path, dest_file_path)
# Out:
# assets/
# conceptbanks/
# concepts/
# data/
# datasets/
# learn_concepts_dataset.py
# learn_concepts_multimodal.py
# LICENSE
# models/
# pcbm_coco_stuff__clip:RN50__broden_clip:RN50_0__lam:0.001__alpha:0.99__seed:42.ckpt
# README.md
# run_info-pcbm_coco_stuff__clip:RN50__broden_clip:RN50_0__lam:0.001__alpha:0.99__seed:42.pkl
# test-embs_coco_stuff__clip:RN50__broden_clip:RN50_0.npy
# test-lbls_coco_stuff__clip:RN50__broden_clip:RN50_0_lbls.npy
# test-proj_coco_stuff__clip:RN50__broden_clip:RN50_0.npy
# train-embs_coco_stuff__clip:RN50__broden_clip:RN50_0.npy
# training_tools/
# train-lbls_coco_stuff__clip:RN50__broden_clip:RN50_0_lbls.npy
# train_pcbm_h.py
# train_pcbm.py
# train-proj_coco_stuff__clip:RN50__broden_clip:RN50_0.npy

# %%
# Train PCBM
# !python train_pcbm.py \
  --concept-bank="./conceptbanks/broden_clip:RN50_0.01_50_42.pkl" \
  --dataset="coco_stuff" \
  --backbone-name="clip:RN50" \
  --out-dir="" \
  --lam=1e-3 \
  --seed=42
# Out:
# Bank path: ./conceptbanks/broden_clip:RN50_0.01_50_42.pkl. 170 concepts will be used.
# Concept Bank is initialized.
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
# Get the saved concepts
import shutil
source_path = '/content/drive/My Drive/results/'
destination_path = './results/'
shutil.copytree(source_path, destination_path)
# Out:
# './results/'

# %%
# %ls results
# Out:
# pcbm_coco_stuff__clip:RN50__broden_clip:RN50_0__lam:0.001__alpha:0.99__seed:42.ckpt
# run_info-pcbm_coco_stuff__clip:RN50__broden_clip:RN50_0__lam:0.001__alpha:0.99__seed:42.pkl
# test-embs_coco_stuff__clip:RN50__broden_clip:RN50_0.npy
# test-lbls_coco_stuff__clip:RN50__broden_clip:RN50_0_lbls.npy
# test-proj_coco_stuff__clip:RN50__broden_clip:RN50_0.npy
# train-embs_coco_stuff__clip:RN50__broden_clip:RN50_0.npy
# train-lbls_coco_stuff__clip:RN50__broden_clip:RN50_0_lbls.npy
# train-proj_coco_stuff__clip:RN50__broden_clip:RN50_0.npy

# %%
# Train PCBM-h
# !python train_pcbm_h.py \
  --out-dir="./results/" \
  --pcbm-path="./results/pcbm_coco_stuff__clip:RN50__broden_clip:RN50_0__lam:0.001__alpha:0.99__seed:42.ckpt" \
  --concept-bank="./conceptbanks/broden_clip:RN50_0.1_50_42.pkl" \
  --device="cuda" \
  --batch-size=64 \
  --dataset="coco_stuff" \
  --seed=42 \
  --num-epochs=10 \
  --lr=0.01 \
  --l2-penalty=0.01 \
  --num-workers=2
# Out:
# 100%|███████████████████████████████████████| 244M/244M [00:02<00:00, 90.2MiB/s]
# Migrating database to v0.23.4
# ...
#
# Extracting annotations to '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# ...
#
# Writing annotations for 10000 downloaded samples to '/root/fiftyone/coco-2017/train/labels.json'
# Dataset info written to '/root/fiftyone/coco-2017/info.json'
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# ...
#
# Writing annotations for 2324 downloaded samples to '/root/fiftyone/coco-2017/validation/labels.json'
# Dataset info written to '/root/fiftyone/coco-2017/info.json'
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
# %ls ../
# Out:
# drive/  FACT_group11/  sample_data/

# %%
seed=42
import shutil

# Save results
source_path = "./results/"
destination_path = f"/content/drive/My Drive/results{seed}/"
shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/My Drive/results42/'

# %% [markdown]
# ---
# **Seed: 42**

# %%
seed=42

# %%
# Our suggested max number of worker in current system is 2.
# Please be aware that excessive worker creation might get DataLoader running slow or even freeze,
#lower the worker number to avoid potential slowness/freeze if necessary.

# Learn concepts
# !python learn_concepts_dataset.py \
  --backbone-name="clip:RN50" \
  --dataset-name="broden" \
  --out-dir="/content/FACT_group11/conceptbanks/" \
  --device="cuda" \
  --seed=$seed \
  --num-workers=2 \
  --batch-size=100 \
  --C=0.1 \
  --n-samples=50
# Out:
# 	 Not enough negative samples for footboard: 98! Sampling with replacement
# 	 Not enough negative samples for ashcan: 98! Sampling with replacement
# 	 Not enough negative samples for motorbike: 98! Sampling with replacement
# 	 Not enough negative samples for granite: 98! Sampling with replacement
# 	 Not enough positive samples for fan: 94! Sampling with replacement
# 	 Not enough negative samples for fan: 98! Sampling with replacement
# 	 Not enough negative samples for eyebrow: 98! Sampling with replacement
# 	 Not enough negative samples for cushion: 98! Sampling with replacement
# 	 Not enough positive samples for can: 86! Sampling with replacement
# 	 Not enough negative samples for can: 98! Sampling with replacement
# 	 Not enough negative samples for bowl: 98! Sampling with replacement
# 	 Not enough negative samples for bucket: 98! Sampling with replacement
# 	 Not enough negative samples for pack: 98! Sampling with replacement
# ...

# %%
import shutil

# Save conceptbanks
source_path = "./conceptbanks/"
destination_path = f"/content/drive/My Drive/conceptbanks{seed}/"
shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/My Drive/conceptbanks42/'

# %%
concept_bank = f"/content/FACT_group11/conceptbanks/broden_clip:RN50_0.1_50_{seed}.pkl"

# Our suggested max number of worker in current system is 2.
# Please be aware that excessive worker creation might get DataLoader running slow or even freeze,
# lower the worker number to avoid potential slowness/freeze if necessary.

# Train PCBM
# !python train_pcbm.py \
  --concept-bank=$concept_bank \
  --out-dir="/content/FACT_group11/results" \
  --dataset="coco_stuff" \
  --backbone-name="clip:RN50" \
  --device="cuda" \
  --seed=$seed \
  --batch-size=64 \
  --num-workers=2 \
  --alpha=0.99\
  --lam=1e-3 \
  --lr=1e-3
# Out:
# Bank path: /content/FACT_group11/conceptbanks/broden_clip:RN50_0.1_50_42.pkl. 170 concepts will be used.
# Concept Bank is initialized.
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
pcbm_path = f"/content/FACT_group11/results/pcbm_coco_stuff__clip:RN50__broden_clip:RN50_0__lam:0.001__alpha:0.99__seed:{seed}.ckpt"

# Train PCBM-h
# !python train_pcbm_h.py \
  --out-dir="/content/FACT_group11/results/" \
  --pcbm-path=$pcbm_path \
  --concept-bank=$concept_bank \
  --device="cuda" \
  --batch-size=64 \
  --dataset="coco_stuff" \
  --seed=$seed \
  --num-epochs=10 \
  --lr=0.01 \
  --l2-penalty=0.01 \
  --num-workers=2
# Out:
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'handbag': Train View Size = 1258, Validation View Size = 292, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
import shutil

# Save results
source_path = "./results/"
destination_path = f"/content/drive/My Drive/results{seed}/"
shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/My Drive/results42/'

# %% [markdown]
# ---
# **Seed: 1**

# %%
seed=1

# %%
# Our suggested max number of worker in current system is 2.
# Please be aware that excessive worker creation might get DataLoader running slow or even freeze,
# lower the worker number to avoid potential slowness/freeze if necessary.

# Learn concepts
# !python learn_concepts_dataset.py \
  --backbone-name="clip:RN50" \
  --dataset-name="broden" \
  --out-dir="/content/FACT_group11/conceptbanks/" \
  --device="cuda" \
  --seed=$seed \
  --num-workers=2 \
  --batch-size=100 \
  --C=0.1 \
  --n-samples=50
# Out:
# 	 Not enough negative samples for footboard: 98! Sampling with replacement
# 	 Not enough negative samples for ashcan: 98! Sampling with replacement
# 	 Not enough negative samples for motorbike: 98! Sampling with replacement
# 	 Not enough negative samples for granite: 98! Sampling with replacement
# 	 Not enough positive samples for fan: 94! Sampling with replacement
# 	 Not enough negative samples for fan: 98! Sampling with replacement
# 	 Not enough negative samples for eyebrow: 98! Sampling with replacement
# 	 Not enough negative samples for cushion: 98! Sampling with replacement
# 	 Not enough positive samples for can: 86! Sampling with replacement
# 	 Not enough negative samples for can: 98! Sampling with replacement
# 	 Not enough negative samples for bowl: 98! Sampling with replacement
# 	 Not enough negative samples for bucket: 98! Sampling with replacement
# 	 Not enough negative samples for pack: 98! Sampling with replacement
# ...

# %%
import shutil

# Save conceptbanks
source_path = "./conceptbanks/"
destination_path = f"/content/drive/My Drive/conceptbanks{seed}/"
shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/My Drive/conceptbanks1/'

# %%
concept_bank = f"/content/FACT_group11/conceptbanks/broden_clip:RN50_0.1_50_{seed}.pkl"

# Our suggested max number of worker in current system is 2.
# Please be aware that excessive worker creation might get DataLoader running slow or even freeze,
# lower the worker number to avoid potential slowness/freeze if necessary.

# Train PCBM
# !python train_pcbm.py \
  --concept-bank=$concept_bank \
  --out-dir="/content/FACT_group11/results" \
  --dataset="coco_stuff" \
  --backbone-name="clip:RN50" \
  --device="cuda" \
  --seed=$seed \
  --batch-size=64 \
  --num-workers=2 \
  --alpha=0.99\
  --lam=1e-3 \
  --lr=1e-3
# Out:
# Bank path: /content/FACT_group11/conceptbanks/broden_clip:RN50_0.1_50_1.pkl. 170 concepts will be used.
# Concept Bank is initialized.
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
pcbm_path = f"/content/FACT_group11/results/pcbm_coco_stuff__clip:RN50__broden_clip:RN50_0__lam:0.001__alpha:0.99__seed:{seed}.ckpt"

# Train PCBM-h
# !python train_pcbm_h.py \
  --out-dir="/content/FACT_group11/results/" \
  --pcbm-path=$pcbm_path \
  --concept-bank=$concept_bank \
  --device="cuda" \
  --batch-size=64 \
  --dataset="coco_stuff" \
  --seed=$seed \
  --num-epochs=10 \
  --lr=0.01 \
  --l2-penalty=0.01 \
  --num-workers=2
# Out:
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'handbag': Train View Size = 1258, Validation View Size = 292, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
import shutil

# Save results
source_path = "./results/"
destination_path = f"/content/drive/My Drive/results{seed}/"
shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/My Drive/results1/'

# %% [markdown]
# ---
# **Seed: 2**

# %%
seed=2

# %%
# Our suggested max number of worker in current system is 2.
# Please be aware that excessive worker creation might get DataLoader running slow or even freeze,
#lower the worker number to avoid potential slowness/freeze if necessary.

# Learn concepts
# !python learn_concepts_dataset.py \
  --backbone-name="clip:RN50" \
  --dataset-name="broden" \
  --out-dir="/content/FACT_group11/conceptbanks/" \
  --device="cuda" \
  --seed=$seed \
  --num-workers=2 \
  --batch-size=100 \
  --C=0.1 \
  --n-samples=50
# Out:
# 	 Not enough negative samples for footboard: 98! Sampling with replacement
# 	 Not enough negative samples for ashcan: 98! Sampling with replacement
# 	 Not enough negative samples for motorbike: 98! Sampling with replacement
# 	 Not enough negative samples for granite: 98! Sampling with replacement
# 	 Not enough positive samples for fan: 94! Sampling with replacement
# 	 Not enough negative samples for fan: 98! Sampling with replacement
# 	 Not enough negative samples for eyebrow: 98! Sampling with replacement
# 	 Not enough negative samples for cushion: 98! Sampling with replacement
# 	 Not enough positive samples for can: 86! Sampling with replacement
# 	 Not enough negative samples for can: 98! Sampling with replacement
# 	 Not enough negative samples for bowl: 98! Sampling with replacement
# 	 Not enough negative samples for bucket: 98! Sampling with replacement
# 	 Not enough negative samples for pack: 98! Sampling with replacement
# ...

# %%
import shutil

# Save conceptbanks
source_path = "./conceptbanks/"
destination_path = f"/content/drive/My Drive/conceptbanks{seed}/"
shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/My Drive/conceptbanks2/'

# %%
concept_bank = f"/content/FACT_group11/conceptbanks/broden_clip:RN50_0.1_50_{seed}.pkl"

# Our suggested max number of worker in current system is 2.
# Please be aware that excessive worker creation might get DataLoader running slow or even freeze,
# lower the worker number to avoid potential slowness/freeze if necessary.

# Train PCBM
# !python train_pcbm.py \
  --concept-bank=$concept_bank \
  --out-dir="/content/FACT_group11/results" \
  --dataset="coco_stuff" \
  --backbone-name="clip:RN50" \
  --device="cuda" \
  --seed=$seed \
  --batch-size=64 \
  --num-workers=2 \
  --alpha=0.99\
  --lam=1e-3 \
  --lr=1e-3
# Out:
# Bank path: /content/FACT_group11/conceptbanks/broden_clip:RN50_0.1_50_2.pkl. 170 concepts will be used.
# Concept Bank is initialized.
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
pcbm_path = f"/content/FACT_group11/results/pcbm_coco_stuff__clip:RN50__broden_clip:RN50_0__lam:0.001__alpha:0.99__seed:{seed}.ckpt"

# Train PCBM-h
# !python train_pcbm_h.py \
  --out-dir="/content/FACT_group11/results/" \
  --pcbm-path=$pcbm_path \
  --concept-bank=$concept_bank \
  --device="cuda" \
  --batch-size=64 \
  --dataset="coco_stuff" \
  --seed=$seed \
  --num-epochs=10 \
  --lr=0.01 \
  --l2-penalty=0.01 \
  --num-workers=2
# Out:
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'handbag': Train View Size = 1258, Validation View Size = 292, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
import shutil

# Save results
source_path = "./results/"
destination_path = f"/content/drive/My Drive/results{seed}/"
shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/My Drive/results2/'

# %% [markdown]
# ---
# **Seed: 3**

# %%
seed=3

# %%
# Our suggested max number of worker in current system is 2.
# Please be aware that excessive worker creation might get DataLoader running slow or even freeze,
#lower the worker number to avoid potential slowness/freeze if necessary.

# Learn concepts
# !python learn_concepts_dataset.py \
  --backbone-name="clip:RN50" \
  --dataset-name="broden" \
  --out-dir="/content/FACT_group11/conceptbanks/" \
  --device="cuda" \
  --seed=$seed \
  --num-workers=2 \
  --batch-size=100 \
  --C=0.1 \
  --n-samples=50
# Out:
# 	 Not enough negative samples for footboard: 98! Sampling with replacement
# 	 Not enough negative samples for ashcan: 98! Sampling with replacement
# 	 Not enough negative samples for motorbike: 98! Sampling with replacement
# 	 Not enough negative samples for granite: 98! Sampling with replacement
# 	 Not enough positive samples for fan: 94! Sampling with replacement
# 	 Not enough negative samples for fan: 98! Sampling with replacement
# 	 Not enough negative samples for eyebrow: 98! Sampling with replacement
# 	 Not enough negative samples for cushion: 98! Sampling with replacement
# 	 Not enough positive samples for can: 86! Sampling with replacement
# 	 Not enough negative samples for can: 98! Sampling with replacement
# 	 Not enough negative samples for bowl: 98! Sampling with replacement
# 	 Not enough negative samples for bucket: 98! Sampling with replacement
# 	 Not enough negative samples for pack: 98! Sampling with replacement
# ...

# %%
import shutil

# Save conceptbanks
source_path = "./conceptbanks/"
destination_path = f"/content/drive/My Drive/conceptbanks{seed}/"
shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/My Drive/conceptbanks3/'

# %%
concept_bank = f"/content/FACT_group11/conceptbanks/broden_clip:RN50_0.1_50_{seed}.pkl"

# Our suggested max number of worker in current system is 2.
# Please be aware that excessive worker creation might get DataLoader running slow or even freeze,
# lower the worker number to avoid potential slowness/freeze if necessary.

# Train PCBM
# !python train_pcbm.py \
  --concept-bank=$concept_bank \
  --out-dir="/content/FACT_group11/results" \
  --dataset="coco_stuff" \
  --backbone-name="clip:RN50" \
  --device="cuda" \
  --seed=$seed \
  --batch-size=64 \
  --num-workers=2 \
  --alpha=0.99\
  --lam=1e-3 \
  --lr=1e-3
# Out:
# Bank path: /content/FACT_group11/conceptbanks/broden_clip:RN50_0.1_50_3.pkl. 170 concepts will be used.
# Concept Bank is initialized.
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
pcbm_path = f"/content/FACT_group11/results/pcbm_coco_stuff__clip:RN50__broden_clip:RN50_0__lam:0.001__alpha:0.99__seed:{seed}.ckpt"

# Train PCBM-h
# !python train_pcbm_h.py \
  --out-dir="/content/FACT_group11/results/" \
  --pcbm-path=$pcbm_path \
  --concept-bank=$concept_bank \
  --device="cuda" \
  --batch-size=64 \
  --dataset="coco_stuff" \
  --seed=$seed \
  --num-epochs=10 \
  --lr=0.01 \
  --l2-penalty=0.01 \
  --num-workers=2
# Out:
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'handbag': Train View Size = 1258, Validation View Size = 292, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
import shutil

# Save results
source_path = "./results/"
destination_path = f"/content/drive/My Drive/results{seed}/"
shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/My Drive/results3/'

# %% [markdown]
# ---
# **Seed: 4**

# %%
seed=4

# %%
# Our suggested max number of worker in current system is 2.
# Please be aware that excessive worker creation might get DataLoader running slow or even freeze,
#lower the worker number to avoid potential slowness/freeze if necessary.

# Learn concepts
# !python learn_concepts_dataset.py \
  --backbone-name="clip:RN50" \
  --dataset-name="broden" \
  --out-dir="/content/FACT_group11/conceptbanks/" \
  --device="cuda" \
  --seed=$seed \
  --num-workers=2 \
  --batch-size=100 \
  --C=0.1 \
  --n-samples=50
# Out:
# 	 Not enough negative samples for footboard: 98! Sampling with replacement
# 	 Not enough negative samples for ashcan: 98! Sampling with replacement
# 	 Not enough negative samples for motorbike: 98! Sampling with replacement
# 	 Not enough negative samples for granite: 98! Sampling with replacement
# 	 Not enough positive samples for fan: 94! Sampling with replacement
# 	 Not enough negative samples for fan: 98! Sampling with replacement
# 	 Not enough negative samples for eyebrow: 98! Sampling with replacement
# 	 Not enough negative samples for cushion: 98! Sampling with replacement
# 	 Not enough positive samples for can: 86! Sampling with replacement
# 	 Not enough negative samples for can: 98! Sampling with replacement
# 	 Not enough negative samples for bowl: 98! Sampling with replacement
# 	 Not enough negative samples for bucket: 98! Sampling with replacement
# 	 Not enough negative samples for pack: 98! Sampling with replacement
# ...

# %%
import shutil

# Save conceptbanks
source_path = "./conceptbanks/"
destination_path = f"/content/drive/My Drive/conceptbanks{seed}/"
shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/My Drive/conceptbanks4/'

# %%
concept_bank = f"/content/FACT_group11/conceptbanks/broden_clip:RN50_0.1_50_{seed}.pkl"

# Our suggested max number of worker in current system is 2.
# Please be aware that excessive worker creation might get DataLoader running slow or even freeze,
# lower the worker number to avoid potential slowness/freeze if necessary.

# Train PCBM
# !python train_pcbm.py \
  --concept-bank=$concept_bank \
  --out-dir="/content/FACT_group11/results" \
  --dataset="coco_stuff" \
  --backbone-name="clip:RN50" \
  --device="cuda" \
  --seed=$seed \
  --batch-size=64 \
  --num-workers=2 \
  --alpha=0.99\
  --lam=1e-3 \
  --lr=1e-3
# Out:
# Bank path: /content/FACT_group11/conceptbanks/broden_clip:RN50_0.1_50_4.pkl. 170 concepts will be used.
# Concept Bank is initialized.
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
pcbm_path = f"/content/FACT_group11/results/pcbm_coco_stuff__clip:RN50__broden_clip:RN50_0__lam:0.001__alpha:0.99__seed:{seed}.ckpt"

# Train PCBM-h
# !python train_pcbm_h.py \
  --out-dir="/content/FACT_group11/results/" \
  --pcbm-path=$pcbm_path \
  --concept-bank=$concept_bank \
  --device="cuda" \
  --batch-size=64 \
  --dataset="coco_stuff" \
  --seed=$seed \
  --num-epochs=10 \
  --lr=0.01 \
  --l2-penalty=0.01 \
  --num-workers=2
# Out:
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'handbag': Train View Size = 1258, Validation View Size = 292, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
import shutil

# Save results
source_path = "./results/"
destination_path = f"/content/drive/My Drive/results{seed}/"
shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/My Drive/results4/'

# %% [markdown]
# ---
# **Seed: 5**

# %%
seed=5

# %%
# Our suggested max number of worker in current system is 2.
# Please be aware that excessive worker creation might get DataLoader running slow or even freeze,
#lower the worker number to avoid potential slowness/freeze if necessary.

# Learn concepts
# !python learn_concepts_dataset.py \
  --backbone-name="clip:RN50" \
  --dataset-name="broden" \
  --out-dir="/content/FACT_group11/conceptbanks/" \
  --device="cuda" \
  --seed=$seed \
  --num-workers=2 \
  --batch-size=100 \
  --C=0.1 \
  --n-samples=50
# Out:
# 	 Not enough negative samples for footboard: 98! Sampling with replacement
# 	 Not enough negative samples for ashcan: 98! Sampling with replacement
# 	 Not enough negative samples for motorbike: 98! Sampling with replacement
# 	 Not enough negative samples for granite: 98! Sampling with replacement
# 	 Not enough positive samples for fan: 94! Sampling with replacement
# 	 Not enough negative samples for fan: 98! Sampling with replacement
# 	 Not enough negative samples for eyebrow: 98! Sampling with replacement
# 	 Not enough negative samples for cushion: 98! Sampling with replacement
# 	 Not enough positive samples for can: 86! Sampling with replacement
# 	 Not enough negative samples for can: 98! Sampling with replacement
# 	 Not enough negative samples for bowl: 98! Sampling with replacement
# 	 Not enough negative samples for bucket: 98! Sampling with replacement
# 	 Not enough negative samples for pack: 98! Sampling with replacement
# ...

# %%
import shutil

# Save conceptbanks
source_path = "./conceptbanks/"
destination_path = f"/content/drive/My Drive/conceptbanks{seed}/"
shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/My Drive/conceptbanks5/'

# %%
concept_bank = f"/content/FACT_group11/conceptbanks/broden_clip:RN50_0.1_50_{seed}.pkl"

# Our suggested max number of worker in current system is 2.
# Please be aware that excessive worker creation might get DataLoader running slow or even freeze,
# lower the worker number to avoid potential slowness/freeze if necessary.

# Train PCBM
# !python train_pcbm.py \
  --concept-bank=$concept_bank \
  --out-dir="/content/FACT_group11/results" \
  --dataset="coco_stuff" \
  --backbone-name="clip:RN50" \
  --device="cuda" \
  --seed=$seed \
  --batch-size=64 \
  --num-workers=2 \
  --alpha=0.99\
  --lam=1e-3 \
  --lr=1e-3
# Out:
# Bank path: /content/FACT_group11/conceptbanks/broden_clip:RN50_0.1_50_5.pkl. 170 concepts will be used.
# Concept Bank is initialized.
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
pcbm_path = f"/content/FACT_group11/results/pcbm_coco_stuff__clip:RN50__broden_clip:RN50_0__lam:0.001__alpha:0.99__seed:{seed}.ckpt"

# Train PCBM-h
# !python train_pcbm_h.py \
  --out-dir="/content/FACT_group11/results/" \
  --pcbm-path=$pcbm_path \
  --concept-bank=$concept_bank \
  --device="cuda" \
  --batch-size=64 \
  --dataset="coco_stuff" \
  --seed=$seed \
  --num-epochs=10 \
  --lr=0.01 \
  --l2-penalty=0.01 \
  --num-workers=2
# Out:
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'handbag': Train View Size = 1258, Validation View Size = 292, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
import shutil

# Save results
source_path = "./results/"
destination_path = f"/content/drive/My Drive/results{seed}/"
shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/My Drive/results5/'

# %% [markdown]
# ---
# **Seed: 6**

# %%
seed=6

# %%
# Our suggested max number of worker in current system is 2.
# Please be aware that excessive worker creation might get DataLoader running slow or even freeze,
#lower the worker number to avoid potential slowness/freeze if necessary.

# Learn concepts
# !python learn_concepts_dataset.py \
  --backbone-name="clip:RN50" \
  --dataset-name="broden" \
  --out-dir="/content/FACT_group11/conceptbanks/" \
  --device="cuda" \
  --seed=$seed \
  --num-workers=2 \
  --batch-size=100 \
  --C=0.1 \
  --n-samples=50
# Out:
# 	 Not enough negative samples for footboard: 98! Sampling with replacement
# 	 Not enough negative samples for ashcan: 98! Sampling with replacement
# 	 Not enough negative samples for motorbike: 98! Sampling with replacement
# 	 Not enough negative samples for granite: 98! Sampling with replacement
# 	 Not enough positive samples for fan: 94! Sampling with replacement
# 	 Not enough negative samples for fan: 98! Sampling with replacement
# 	 Not enough negative samples for eyebrow: 98! Sampling with replacement
# 	 Not enough negative samples for cushion: 98! Sampling with replacement
# 	 Not enough positive samples for can: 86! Sampling with replacement
# 	 Not enough negative samples for can: 98! Sampling with replacement
# 	 Not enough negative samples for bowl: 98! Sampling with replacement
# 	 Not enough negative samples for bucket: 98! Sampling with replacement
# 	 Not enough negative samples for pack: 98! Sampling with replacement
# ...

# %%
import shutil

# Save conceptbanks
source_path = "./conceptbanks/"
destination_path = f"/content/drive/My Drive/conceptbanks{seed}/"
shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/My Drive/conceptbanks6/'

# %%
concept_bank = f"/content/FACT_group11/conceptbanks/broden_clip:RN50_0.1_50_{seed}.pkl"

# Our suggested max number of worker in current system is 2.
# Please be aware that excessive worker creation might get DataLoader running slow or even freeze,
# lower the worker number to avoid potential slowness/freeze if necessary.

# Train PCBM
# !python train_pcbm.py \
  --concept-bank=$concept_bank \
  --out-dir="/content/FACT_group11/results" \
  --dataset="coco_stuff" \
  --backbone-name="clip:RN50" \
  --device="cuda" \
  --seed=$seed \
  --batch-size=64 \
  --num-workers=2 \
  --alpha=0.99\
  --lam=1e-3 \
  --lr=1e-3
# Out:
# Bank path: /content/FACT_group11/conceptbanks/broden_clip:RN50_0.1_50_6.pkl. 170 concepts will be used.
# Concept Bank is initialized.
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
pcbm_path = f"/content/FACT_group11/results/pcbm_coco_stuff__clip:RN50__broden_clip:RN50_0__lam:0.001__alpha:0.99__seed:{seed}.ckpt"

# Train PCBM-h
# !python train_pcbm_h.py \
  --out-dir="/content/FACT_group11/results/" \
  --pcbm-path=$pcbm_path \
  --concept-bank=$concept_bank \
  --device="cuda" \
  --batch-size=64 \
  --dataset="coco_stuff" \
  --seed=$seed \
  --num-epochs=10 \
  --lr=0.01 \
  --l2-penalty=0.01 \
  --num-workers=2
# Out:
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'handbag': Train View Size = 1258, Validation View Size = 292, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
import shutil

# Save results
source_path = "./results/"
destination_path = f"/content/drive/My Drive/results{seed}/"
shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/My Drive/results6/'

# %% [markdown]
# ---
# **Seed: 7**

# %%
seed=7

# %%
# Our suggested max number of worker in current system is 2.
# Please be aware that excessive worker creation might get DataLoader running slow or even freeze,
#lower the worker number to avoid potential slowness/freeze if necessary.

# Learn concepts
# !python learn_concepts_dataset.py \
  --backbone-name="clip:RN50" \
  --dataset-name="broden" \
  --out-dir="/content/FACT_group11/conceptbanks/" \
  --device="cuda" \
  --seed=$seed \
  --num-workers=2 \
  --batch-size=100 \
  --C=0.1 \
  --n-samples=50
# Out:
# 	 Not enough negative samples for footboard: 98! Sampling with replacement
# 	 Not enough negative samples for ashcan: 98! Sampling with replacement
# 	 Not enough negative samples for motorbike: 98! Sampling with replacement
# 	 Not enough negative samples for granite: 98! Sampling with replacement
# 	 Not enough positive samples for fan: 94! Sampling with replacement
# 	 Not enough negative samples for fan: 98! Sampling with replacement
# 	 Not enough negative samples for eyebrow: 98! Sampling with replacement
# 	 Not enough negative samples for cushion: 98! Sampling with replacement
# 	 Not enough positive samples for can: 86! Sampling with replacement
# 	 Not enough negative samples for can: 98! Sampling with replacement
# 	 Not enough negative samples for bowl: 98! Sampling with replacement
# 	 Not enough negative samples for bucket: 98! Sampling with replacement
# 	 Not enough negative samples for pack: 98! Sampling with replacement
# ...

# %%
import shutil

# Save conceptbanks
source_path = "./conceptbanks/"
destination_path = f"/content/drive/My Drive/conceptbanks{seed}/"
shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/My Drive/conceptbanks7/'

# %%
concept_bank = f"/content/FACT_group11/conceptbanks/broden_clip:RN50_0.1_50_{seed}.pkl"

# Our suggested max number of worker in current system is 2.
# Please be aware that excessive worker creation might get DataLoader running slow or even freeze,
# lower the worker number to avoid potential slowness/freeze if necessary.

# Train PCBM
# !python train_pcbm.py \
  --concept-bank=$concept_bank \
  --out-dir="/content/FACT_group11/results" \
  --dataset="coco_stuff" \
  --backbone-name="clip:RN50" \
  --device="cuda" \
  --seed=$seed \
  --batch-size=64 \
  --num-workers=2 \
  --alpha=0.99\
  --lam=1e-3 \
  --lr=1e-3
# Out:
# Bank path: /content/FACT_group11/conceptbanks/broden_clip:RN50_0.1_50_7.pkl. 170 concepts will be used.
# Concept Bank is initialized.
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
pcbm_path = f"/content/FACT_group11/results/pcbm_coco_stuff__clip:RN50__broden_clip:RN50_0__lam:0.001__alpha:0.99__seed:{seed}.ckpt"

# Train PCBM-h
# !python train_pcbm_h.py \
  --out-dir="/content/FACT_group11/results/" \
  --pcbm-path=$pcbm_path \
  --concept-bank=$concept_bank \
  --device="cuda" \
  --batch-size=64 \
  --dataset="coco_stuff" \
  --seed=$seed \
  --num-epochs=10 \
  --lr=0.01 \
  --l2-penalty=0.01 \
  --num-workers=2
# Out:
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'handbag': Train View Size = 1258, Validation View Size = 292, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
import shutil

# Save results
source_path = "./results/"
destination_path = f"/content/drive/My Drive/results{seed}/"
shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/My Drive/results7/'

# %% [markdown]
# ---
# **Seed: 8**

# %%
seed=8

# %%
# Our suggested max number of worker in current system is 2.
# Please be aware that excessive worker creation might get DataLoader running slow or even freeze,
#lower the worker number to avoid potential slowness/freeze if necessary.

# Learn concepts
# !python learn_concepts_dataset.py \
  --backbone-name="clip:RN50" \
  --dataset-name="broden" \
  --out-dir="/content/FACT_group11/conceptbanks/" \
  --device="cuda" \
  --seed=$seed \
  --num-workers=2 \
  --batch-size=100 \
  --C=0.1 \
  --n-samples=50
# Out:
# 	 Not enough negative samples for footboard: 98! Sampling with replacement
# 	 Not enough negative samples for ashcan: 98! Sampling with replacement
# 	 Not enough negative samples for motorbike: 98! Sampling with replacement
# 	 Not enough negative samples for granite: 98! Sampling with replacement
# 	 Not enough positive samples for fan: 94! Sampling with replacement
# 	 Not enough negative samples for fan: 98! Sampling with replacement
# 	 Not enough negative samples for eyebrow: 98! Sampling with replacement
# 	 Not enough negative samples for cushion: 98! Sampling with replacement
# 	 Not enough positive samples for can: 86! Sampling with replacement
# 	 Not enough negative samples for can: 98! Sampling with replacement
# 	 Not enough negative samples for bowl: 98! Sampling with replacement
# 	 Not enough negative samples for bucket: 98! Sampling with replacement
# 	 Not enough negative samples for pack: 98! Sampling with replacement
# ...

# %%
import shutil

# Save conceptbanks
source_path = "./conceptbanks/"
destination_path = f"/content/drive/My Drive/conceptbanks{seed}/"
shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/My Drive/conceptbanks8/'

# %%
concept_bank = f"/content/FACT_group11/conceptbanks/broden_clip:RN50_0.1_50_{seed}.pkl"

# Our suggested max number of worker in current system is 2.
# Please be aware that excessive worker creation might get DataLoader running slow or even freeze,
# lower the worker number to avoid potential slowness/freeze if necessary.

# Train PCBM
# !python train_pcbm.py \
  --concept-bank=$concept_bank \
  --out-dir="/content/FACT_group11/results" \
  --dataset="coco_stuff" \
  --backbone-name="clip:RN50" \
  --device="cuda" \
  --seed=$seed \
  --batch-size=64 \
  --num-workers=2 \
  --alpha=0.99\
  --lam=1e-3 \
  --lr=1e-3
# Out:
# Bank path: /content/FACT_group11/conceptbanks/broden_clip:RN50_0.1_50_8.pkl. 170 concepts will be used.
# Concept Bank is initialized.
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
pcbm_path = f"/content/FACT_group11/results/pcbm_coco_stuff__clip:RN50__broden_clip:RN50_0__lam:0.001__alpha:0.99__seed:{seed}.ckpt"

# Train PCBM-h
# !python train_pcbm_h.py \
  --out-dir="/content/FACT_group11/results/" \
  --pcbm-path=$pcbm_path \
  --concept-bank=$concept_bank \
  --device="cuda" \
  --batch-size=64 \
  --dataset="coco_stuff" \
  --seed=$seed \
  --num-epochs=10 \
  --lr=0.01 \
  --l2-penalty=0.01 \
  --num-workers=2
# Out:
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'handbag': Train View Size = 1258, Validation View Size = 292, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
import shutil

# Save results
source_path = "./results/"
destination_path = f"/content/drive/My Drive/results{seed}/"
shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/My Drive/results8/'

# %% [markdown]
# ---
# **Seed: 9**

# %%
seed=9

# %%
# Our suggested max number of worker in current system is 2.
# Please be aware that excessive worker creation might get DataLoader running slow or even freeze,
#lower the worker number to avoid potential slowness/freeze if necessary.

# Learn concepts
# !python learn_concepts_dataset.py \
  --backbone-name="clip:RN50" \
  --dataset-name="broden" \
  --out-dir="/content/FACT_group11/conceptbanks/" \
  --device="cuda" \
  --seed=$seed \
  --num-workers=2 \
  --batch-size=100 \
  --C=0.1 \
  --n-samples=50
# Out:
# 	 Not enough negative samples for footboard: 98! Sampling with replacement
# 	 Not enough negative samples for ashcan: 98! Sampling with replacement
# 	 Not enough negative samples for motorbike: 98! Sampling with replacement
# 	 Not enough negative samples for granite: 98! Sampling with replacement
# 	 Not enough positive samples for fan: 94! Sampling with replacement
# 	 Not enough negative samples for fan: 98! Sampling with replacement
# 	 Not enough negative samples for eyebrow: 98! Sampling with replacement
# 	 Not enough negative samples for cushion: 98! Sampling with replacement
# 	 Not enough positive samples for can: 86! Sampling with replacement
# 	 Not enough negative samples for can: 98! Sampling with replacement
# 	 Not enough negative samples for bowl: 98! Sampling with replacement
# 	 Not enough negative samples for bucket: 98! Sampling with replacement
# 	 Not enough negative samples for pack: 98! Sampling with replacement
# ...

# %%
import shutil

# Save conceptbanks
source_path = "./conceptbanks/"
destination_path = f"/content/drive/My Drive/conceptbanks{seed}/"
shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/My Drive/conceptbanks9/'

# %%
concept_bank = f"/content/FACT_group11/conceptbanks/broden_clip:RN50_0.1_50_{seed}.pkl"

# Our suggested max number of worker in current system is 2.
# Please be aware that excessive worker creation might get DataLoader running slow or even freeze,
# lower the worker number to avoid potential slowness/freeze if necessary.

# Train PCBM
# !python train_pcbm.py \
  --concept-bank=$concept_bank \
  --out-dir="/content/FACT_group11/results" \
  --dataset="coco_stuff" \
  --backbone-name="clip:RN50" \
  --device="cuda" \
  --seed=$seed \
  --batch-size=64 \
  --num-workers=2 \
  --alpha=0.99\
  --lam=1e-3 \
  --lr=1e-3
# Out:
# Bank path: /content/FACT_group11/conceptbanks/broden_clip:RN50_0.1_50_9.pkl. 170 concepts will be used.
# Concept Bank is initialized.
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
pcbm_path = f"/content/FACT_group11/results/pcbm_coco_stuff__clip:RN50__broden_clip:RN50_0__lam:0.001__alpha:0.99__seed:{seed}.ckpt"

# Train PCBM-h
# !python train_pcbm_h.py \
  --out-dir="/content/FACT_group11/results/" \
  --pcbm-path=$pcbm_path \
  --concept-bank=$concept_bank \
  --device="cuda" \
  --batch-size=64 \
  --dataset="coco_stuff" \
  --seed=$seed \
  --num-epochs=10 \
  --lr=0.01 \
  --l2-penalty=0.01 \
  --num-workers=2
# Out:
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading 'coco-2017' split 'train'
#
# Dataset 'coco-2017-train-10000' created
# ...
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 2324 (<5000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#
# Dataset 'coco-2017-validation-5000' created
# Class 'cup': Train View Size = 1684, Validation View Size = 390, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'wine glass': Train View Size = 467, Validation View Size = 110, Sampled Train View Size = 500, Sampled Validation View Size = 250
# Class 'handbag': Train View Size = 1258, Validation View Size = 292, Sampled Train View Size = 500, Sampled Validation View Size = 250
# ...

# %%
import shutil

# Save results
source_path = "./results/"
destination_path = f"/content/drive/My Drive/results{seed}/"
shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/My Drive/results9/'
