# %%
# !git clone https://OliverSavolainen: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@github.com/valentina98/FACT_group11
# Out:
# Cloning into 'FACT_group11'...
# remote: Enumerating objects: 41440, done.
# remote: Counting objects: 100% (767/767), done.
# remote: Compressing objects: 100% (318/318), done.
# remote: Total 41440 (delta 500), reused 704 (delta 449), pack-reused 40673
# Receiving objects: 100% (41440/41440), 2.54 GiB | 40.06 MiB/s, done.
# Resolving deltas: 100% (553/553), done.
# Updating files: 100% (56330/56330), done.

# %%
# %cd ..
# %cd content/FACT_group11
# Out:
# /content
# [Errno 2] No such file or directory: 'content/FACT_group11'
# /content

# %%
import os

# %%
# !pip install pytorchcv

# %%
# !git checkout colab_conf
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git pull
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
OUTPUT_DIR="/content/FACT_group11/conceptbanks/"

# %%
# !pip install ftfy regex tqdm
# !pip install git+https://github.com/openai/CLIP.git
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-z47lyj9e
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-z47lyj9e
#   Resolved https://github.com/openai/CLIP.git to commit a1d071733d7111c9c014f024669f959182114e33
#   Preparing metadata (setup.py) ... done
# ...

# %%
OUTPUT_DIR="/content/FACT_group11/conceptbanks/"

# %%
# %cd FACT_group11/
# Out:
# /content/FACT_group11

# %%
# !python train_original.py --out-dir=$OUTPUT_DIR --lr=1e-3
# Out:
# [nltk_data] Downloading package framenet_v17 to /root/nltk_data...
# [nltk_data]   Package framenet_v17 is already up-to-date!
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# 100% 3125/3125 [02:21<00:00, 22.05it/s]
# 100% 625/625 [00:27<00:00, 23.02it/s]
# Epoch 1/10, Loss: 1.4849, Accuracy: 0.6199
# 100% 3125/3125 [02:18<00:00, 22.53it/s]
# 100% 625/625 [00:26<00:00, 23.20it/s]
# Epoch 2/10, Loss: 1.1604, Accuracy: 0.6401
# 100% 3125/3125 [02:20<00:00, 22.25it/s]
# 100% 625/625 [00:27<00:00, 23.01it/s]
# Epoch 3/10, Loss: 1.0877, Accuracy: 0.6523
# 100% 3125/3125 [02:18<00:00, 22.51it/s]
# 100% 625/625 [00:28<00:00, 21.85it/s]
# Epoch 4/10, Loss: 1.0510, Accuracy: 0.6606
# 100% 3125/3125 [02:19<00:00, 22.42it/s]
# 100% 625/625 [00:26<00:00, 23.49it/s]
# Epoch 5/10, Loss: 1.0301, Accuracy: 0.6672
# 100% 3125/3125 [02:17<00:00, 22.75it/s]
# ...

# %%
# !python train_original.py --dataset="cifar100" --out-dir=$OUTPUT_DIR
# Out:
# [nltk_data] Downloading package framenet_v17 to /root/nltk_data...
# [nltk_data]   Package framenet_v17 is already up-to-date!
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# 100% 3125/3125 [02:19<00:00, 22.33it/s]
# 100% 625/625 [00:26<00:00, 23.20it/s]
# Epoch 1/10, Loss: 2.7986, Accuracy: 0.3955
#   8% 260/3125 [00:12<01:55, 24.75it/s]Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x79eedb7e7370>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 149, in join
# ...

# %%
# !python train_original.py --out-dir=$OUTPUT_DIR --dataset="cub" --backbone_name="resnet18_cub" --epochs=0
# Out:
# [nltk_data] Downloading package framenet_v17 to /root/nltk_data...
# [nltk_data]   Package framenet_v17 is already up-to-date!
# 200 num classes for cub
# 4796 training set size
# 5794 test set size
# 100% 363/363 [00:33<00:00, 10.75it/s]
# Accuracy: 0.6206

# %%
# !git pull
# Out:
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0
# Unpacking objects: 100% (3/3), 326 bytes | 326.00 KiB/s, done.
# From https://github.com/valentina98/FACT_group11
#    03d77a1f..21cb6932  colab_conf -> origin/colab_conf
# Updating 03d77a1f..21cb6932
# Fast-forward
#  train_bert_original.py | 3 ++-
#  1 file changed, 2 insertions(+), 1 deletion(-)

# %%
# !python train_bert_original.py
# Out:
# [nltk_data] Downloading package framenet_v17 to /root/nltk_data...
# [nltk_data]   Package framenet_v17 is already up-to-date!
# 100% 708/708 [07:36<00:00,  1.55it/s]
# 100% 708/708 [07:32<00:00,  1.57it/s]
# 100% 708/708 [07:32<00:00,  1.56it/s]
# 100% 471/471 [04:48<00:00,  1.63it/s]
# Accuracy: 0.15560276155071695

# %%
# !python learn_concepts_dataset.py --dataset-name="frame" --backbone-name="bert" --C 0.1 --out-dir=$OUTPUT_DIR --seed=42 --num-workers=2
# Out:
# [nltk_data] Downloading package framenet_v17 to /root/nltk_data...
# [nltk_data]   Package framenet_v17 is already up-to-date!
# Skipping Cause_to_burn
# Skipping Cause_to_land
# Skipping Change_of_phase_scenario
# Skipping Citing
# Skipping Collocation_image_schema
# Skipping Commerce_collect
# Skipping Commerce_goods-transfer
# Skipping Commerce_money-transfer
# Skipping Commutative_process
# Skipping Commutative_statement
# Skipping Condition_symptom_relation
# Skipping Conditional_scenario
# Skipping Emergency
# Skipping Emotions
# Skipping Emotions_by_possibility
# Skipping Employee_scenario
# Skipping Employer_scenario
# Skipping Employment_continue
# Skipping Employment_end
# Skipping Employment_scenario
# Skipping Employment_start
# Skipping Event_endstate
# Skipping Event_initial_state
# Skipping Exemplariness
# Skipping Fall_for
# Skipping Fire_break
# Skipping Fire_emergency_scenario
# Skipping Fire_end_scenario
# Skipping Fire_going_out
# Skipping Fire_stopping_scenario
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

import os

# %%
# %cd data

# %%
# !python get_framenet_sentences.py

# %%
# !python train_pcbm.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --backbone-name="bert" --out-dir=$OUTPUT_DIR --lam=0.0001 --seed=42 --num-workers=2
# Out:
# [nltk_data] Downloading package framenet_v17 to /root/nltk_data...
# [nltk_data]   Package framenet_v17 is already up-to-date!
# Bank path: /content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl. 1014 concepts will be used.
# Concept Bank is initialized.
# torch.Size([1014, 768])
# 100% 177/177 [08:03<00:00,  2.73s/it]
# 100% 118/118 [05:16<00:00,  2.69s/it]
# 0: 0.36990595611285265
# 1: 0.5141388174807198
# 2: 0.5203045685279187
# 3: 0.4489795918367347
# 4: 0.3922077922077922
# 5: 0.5240506329113924
# 6: 0.7076923076923077
# 7: 0.6237373737373737
# 8: 0.5703517587939698
# 9: 0.7455919395465995
# 10: 0.8095238095238095
# 11: 0.5555555555555556
# 12: 0.4631043256997455
# 13: 0.7777777777777778
# 14: 0.682741116751269
# 15: 0.6130653266331658
# 16: 0.4642857142857143
# 17: 0.7101063829787234
# 18: 0.32903225806451614
# 19: 0.2908366533864542
# Class : alt.atheism
# 	 1 - Military: 25.609
# 	 2 - Cause_change: 17.908
# 	 3 - Prominence: 16.930
# 	 4 - Experiencer_focus: 15.471
# ...

# %%
# !python train_pcbm.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --backbone-name="bert" --out-dir=$OUTPUT_DIR --lam=0.0001 --seed=1 --num-workers=2

# %%
# !python train_pcbm.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --backbone-name="bert" --out-dir=$OUTPUT_DIR --lam=0.0001 --seed=42 --num-workers=2!python train_pcbm.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --backbone-name="bert" --out-dir=$OUTPUT_DIR --lam=0.0001 --seed=2 --num-workers=2

# %%
# !python train_pcbm.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --backbone-name="bert" --out-dir=$OUTPUT_DIR --lam=0.0001 --seed=3 --num-workers=2

# %%
# !python train_pcbm.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --backbone-name="bert" --out-dir=$OUTPUT_DIR --lam=0.0001 --seed=4 --num-workers=2

# %%
# !python train_pcbm.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --backbone-name="bert" --out-dir=$OUTPUT_DIR --lam=0.0001 --seed=5 --num-workers=2

# %%
# !python train_pcbm.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --backbone-name="bert" --out-dir=$OUTPUT_DIR --lam=0.0001 --seed=6 --num-workers=2

# %%
# !python train_pcbm.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --backbone-name="bert" --out-dir=$OUTPUT_DIR --lam=0.0001 --seed=42 --num-workers=2!python train_pcbm.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --backbone-name="bert" --out-dir=$OUTPUT_DIR --lam=0.0001 --seed=7 --num-workers=2

# %%
# !python train_pcbm.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --backbone-name="bert" --out-dir=$OUTPUT_DIR --lam=0.0001 --seed=8 --num-workers=2

# %%
# !python train_pcbm.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --backbone-name="bert" --out-dir=$OUTPUT_DIR --lam=0.0001 --seed=9 --num-workers=2

# %%
# !python train_pcbm_h.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --out-dir=$OUTPUT_DIR --pcbm-path="/content/FACT_group11/conceptbanks/pcbm_20ng__bert__frame_bert_0__lam:0.0001__alpha:0.99__seed:42.ckpt" --seed=42
# Out:
# [nltk_data] Downloading package framenet_v17 to /root/nltk_data...
# [nltk_data]   Package framenet_v17 is already up-to-date!
# Epoch: 1
#   0% 0/177 [00:00<?, ?it/s]
# Avg. CELoss: 35.142 Avg. Accuracy: 0.703:   0% 0/177 [00:00<?, ?it/s]
# Avg. CELoss: 22.926 Avg. Accuracy: 0.695:   0% 0/177 [00:00<?, ?it/s]
# Avg. CELoss: 21.008 Avg. Accuracy: 0.698:   0% 0/177 [00:00<?, ?it/s]
# Avg. CELoss: 20.050 Avg. Accuracy: 0.704:   0% 0/177 [00:00<?, ?it/s]
# Avg. CELoss: 20.000 Avg. Accuracy: 0.708:   0% 0/177 [00:00<?, ?it/s]
# Avg. CELoss: 20.060 Avg. Accuracy: 0.708:   0% 0/177 [00:00<?, ?it/s]
# Avg. CELoss: 19.906 Avg. Accuracy: 0.708:   0% 0/177 [00:00<?, ?it/s]
# Avg. CELoss: 20.125 Avg. Accuracy: 0.710:   0% 0/177 [00:00<?, ?it/s]
# Avg. CELoss: 20.207 Avg. Accuracy: 0.710:   0% 0/177 [00:01<?, ?it/s]
# Avg. CELoss: 20.144 Avg. Accuracy: 0.712:   0% 0/177 [00:01<?, ?it/s]
# 100% 177/177 [00:01<00:00, 146.36it/s]
#
#   0% 0/118 [00:00<?, ?it/s]
#
#   0% 0/118 [00:00<?, ?it/s]
# ...

# %%
# !python train_pcbm_h.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --out-dir=$OUTPUT_DIR --pcbm-path="/content/FACT_group11/conceptbanks/pcbm_20ng__bert__frame_bert_0__lam:0.0001__alpha:0.99__seed:1.ckpt" --seed=1

# %%
# !python train_pcbm_h.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --out-dir=$OUTPUT_DIR --pcbm-path="/content/FACT_group11/conceptbanks/pcbm_20ng__bert__frame_bert_0__lam:0.0001__alpha:0.99__seed:2.ckpt" --seed=2

# %%
# !python train_pcbm_h.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --out-dir=$OUTPUT_DIR --pcbm-path="/content/FACT_group11/conceptbanks/pcbm_20ng__bert__frame_bert_0__lam:0.0001__alpha:0.99__seed:3.ckpt" --seed=3

# %%
# !python train_pcbm_h.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --out-dir=$OUTPUT_DIR --pcbm-path="/content/FACT_group11/conceptbanks/pcbm_20ng__bert__frame_bert_0__lam:0.0001__alpha:0.99__seed:4.ckpt" --seed=4

# %%
# !python train_pcbm_h.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --out-dir=$OUTPUT_DIR --pcbm-path="/content/FACT_group11/conceptbanks/pcbm_20ng__bert__frame_bert_0__lam:0.0001__alpha:0.99__seed:5.ckpt" --seed=5

# %%
# !python train_pcbm_h.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --out-dir=$OUTPUT_DIR --pcbm-path="/content/FACT_group11/conceptbanks/pcbm_20ng__bert__frame_bert_0__lam:0.0001__alpha:0.99__seed:6.ckpt" --seed=6

# %%
# !python train_pcbm_h.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --out-dir=$OUTPUT_DIR --pcbm-path="/content/FACT_group11/conceptbanks/pcbm_20ng__bert__frame_bert_0__lam:0.0001__alpha:0.99__seed:7.ckpt" --seed=7

# %%
# !python train_pcbm_h.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --out-dir=$OUTPUT_DIR --pcbm-path="/content/FACT_group11/conceptbanks/pcbm_20ng__bert__frame_bert_0__lam:0.0001__alpha:0.99__seed:8.ckpt" --seed=8

# %%
# !python train_pcbm_h.py --concept-bank="/content/FACT_group11/conceptbanks/frame_bert_0.1_50_42.pkl" --dataset="20ng" --out-dir=$OUTPUT_DIR --pcbm-path="/content/FACT_group11/conceptbanks/pcbm_20ng__bert__frame_bert_0__lam:0.0001__alpha:0.99__seed:9.ckpt" --seed=9

# %%
K_cifar10 = 10
K_cifar100 = 100
N_c_cifar10_mm = 175
N_c_cifar100_mm = 440
lam_cifar10_mm = 2 / (K_cifar10 * N_c_cifar10_mm)
lam_cifar100_mm = 2 / (K_cifar100 * N_c_cifar100_mm)

# %%
# !python learn_concepts_multimodal.py --backbone-name="clip:RN50" --classes=20ng --out-dir=$OUTPUT_DIR --recurse=1
# Out:
# Pulling concepts for Atheism
# Pulling concepts for Computer Graphics
# Pulling concepts for Windows Operating System
# Pulling concepts for IBM
# Pulling concepts for Macintosh
# Pulling concepts for GUI
# Pulling concepts for Marketplace
# Pulling concepts for Automobiles
# Pulling concepts for Motorbikes
# Pulling concepts for Baseball
# Pulling concepts for Hockey
# Pulling concepts for Cryptography
# Pulling concepts for Electronics
# Pulling concepts for Medicine
# Pulling concepts for Space Exploration
# Pulling concepts for Christianity
# Pulling concepts for Gun Politics
# Pulling concepts for Middle Eastern Politics
# Pulling concepts for General Politics
# Pulling concepts for Religion
# ...

# %%
# !python train_pcbm.py --concept-bank="/content/FACT_group11/conceptbanks/multimodal_concept_clip:RN50_20ng_recurse:1.pkl" --dataset="20ng" --backbone-name="bert" --out-dir=$OUTPUT_DIR --lam=0.0001 --seed=42
# Out:
# [nltk_data] Downloading package framenet_v17 to /root/nltk_data...
# [nltk_data]   Package framenet_v17 is already up-to-date!
# Bank path: /content/FACT_group11/conceptbanks/multimodal_concept_clip:RN50_20ng_recurse:1.pkl. 648 concepts will be used.
# Concept Bank is initialized.
# torch.Size([648, 768])
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 0: 0.31347962382445144
# 1: 0.5012853470437018
# 2: 0.5050761421319797
# 3: 0.40561224489795916
# 4: 0.4077922077922078
# 5: 0.5189873417721519
# 6: 0.6871794871794872
# 7: 0.5833333333333334
# ...

# %%
# !python train_pcbm_h.py --concept-bank="/content/FACT_group11/conceptbanks/multimodal_concept_clip:RN50_20ng_recurse:1.pkl" --dataset="20ng" --out-dir=$OUTPUT_DIR --pcbm-path="/content/FACT_group11/conceptbanks/pcbm_20ng__bert__multimodal_concept_clip:RN50_20ng_recurse:1__lam:0.0001__alpha:0.99__seed:42.ckpt" --seed=42
# Out:
# [nltk_data] Downloading package framenet_v17 to /root/nltk_data...
# [nltk_data]   Package framenet_v17 is already up-to-date!
# Epoch: 1
#   0% 0/177 [00:00<?, ?it/s]
# Avg. CELoss: 3.977 Avg. Accuracy: 0.688:   0% 0/177 [00:00<?, ?it/s]
# Avg. CELoss: 3.420 Avg. Accuracy: 0.720:   0% 0/177 [00:00<?, ?it/s]
# Avg. CELoss: 3.589 Avg. Accuracy: 0.724:   0% 0/177 [00:00<?, ?it/s]
# Avg. CELoss: 3.583 Avg. Accuracy: 0.725:   0% 0/177 [00:00<?, ?it/s]
# Avg. CELoss: 3.582 Avg. Accuracy: 0.727:   0% 0/177 [00:00<?, ?it/s]
# Avg. CELoss: 3.530 Avg. Accuracy: 0.730:   0% 0/177 [00:00<?, ?it/s]
# Avg. CELoss: 3.488 Avg. Accuracy: 0.731:   0% 0/177 [00:01<?, ?it/s]
# Avg. CELoss: 3.538 Avg. Accuracy: 0.734:   0% 0/177 [00:01<?, ?it/s]
# Avg. CELoss: 3.599 Avg. Accuracy: 0.734:   0% 0/177 [00:01<?, ?it/s]
# Avg. CELoss: 3.619 Avg. Accuracy: 0.733:   0% 0/177 [00:01<?, ?it/s]
# 100% 177/177 [00:01<00:00, 129.05it/s]
#
#   0% 0/118 [00:00<?, ?it/s]
#
#   0% 0/118 [00:00<?, ?it/s]
# ...

# %%
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0
# Unpacking objects: 100% (3/3), 283 bytes | 283.00 KiB/s, done.
# From https://github.com/valentina98/FACT_group11
#    f4b00fb4..0231cea2  colab_conf -> origin/colab_conf
# Updating f4b00fb4..0231cea2
# Fast-forward
#  learn_concepts_multimodal.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)
